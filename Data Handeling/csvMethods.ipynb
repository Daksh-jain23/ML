# %% [markdown]
# 1. Imoprting Pandas

# %%
import pandas as pd

# %% [markdown]
# 2. Read file

# %%
df = pd.read_csv("D:\\Code\\Python\\Class\\My Class\\DataSet\\Pokemon\\pokemon.csv")
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
# ...

# %% [markdown]
# 3. Read CSV using url

# %%
url = ''
df = pd.read_csv(url)

# %% [markdown]
# 4. sep parameter (csv - comma seperated value) can be chnage to tab or anything

# %%
pd.read_csv("D:\\Code\\Python\\Class\\My Class\\DataSet\\kagglehub\\Pokemon\\pokemon.csv", sep = '\t')
# Out:
#     abilities,against_bug,against_dark,against_dragon,against_electric,against_fairy,against_fight,against_fire,against_flying,against_ghost,against_grass,against_ground,against_ice,against_normal,against_poison,against_psychic,against_rock,against_steel,against_water,attack,base_egg_steps,base_happiness,base_total,capture_rate,classfication,defense,experience_growth,height_m,hp,japanese_name,name,percentage_male,pokedex_number,sp_attack,sp_defense,speed,type1,type2,weight_kg,generation,is_legendary
# 0    ['Overgrow', 'Chlorophyll'],1,1,1,0.5,0.5,0.5,...
# 1    ['Overgrow', 'Chlorophyll'],1,1,1,0.5,0.5,0.5,...
# 2    ['Overgrow', 'Chlorophyll'],1,1,1,0.5,0.5,0.5,...
# 3    ['Blaze', 'Solar Power'],0.5,1,1,1,0.5,1,0.5,1...
# 4    ['Blaze', 'Solar Power'],0.5,1,1,1,0.5,1,0.5,1...
# ..                                                 ...
# 796  ['Beast Boost'],0.25,1,0.5,2,0.5,1,2,0.5,1,0.2...
# 797  ['Beast Boost'],1,1,0.5,0.5,0.5,2,4,1,1,0.25,1...
# ...

# %% [markdown]
# 5. index col

# %%
pd.read_csv("D:\\Code\\Python\\Class\\My Class\\DataSet\\kagglehub\\Pokemon\\pokemon.csv", index_col='name')
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']         1.00           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']         1.00           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']         1.00           1.0
# Charmander     ['Blaze', 'Solar Power']         0.50           1.0
# Charmeleon     ['Blaze', 'Solar Power']         0.50           1.0
# ...                                 ...          ...           ...
# Celesteela              ['Beast Boost']         0.25           1.0
# Kartana                 ['Beast Boost']         1.00           1.0
# Guzzlord                ['Beast Boost']         2.00           0.5
# Necrozma                ['Prism Armor']         2.00           2.0
# Magearna                 ['Soul-Heart']         0.25           0.5
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# ...

# %% [markdown]
# 6.Header

# %%
pd.read_csv('test.csv', header='1')

# %% [markdown]
# 7. use-col

# %%
pd.read_csv("D:\\Code\\Python\\Class\\My Class\\DataSet\\kagglehub\\Pokemon\\pokemon.csv",\
                 usecols=['name'] )
# Out:
#            name
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# ..          ...
# 796  Celesteela
# 797     Kartana
# 798    Guzzlord
# 799    Necrozma
# 800    Magearna
#
# [801 rows x 1 columns]
